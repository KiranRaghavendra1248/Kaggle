# %%
import pandas as pd
import numpy as np
data=pd.read_csv(r'F:\Machine learning\Linear Regression DS\advertising.csv')

# %%
data.shape
# Out:
# (200, 4)

# %%
data.Sales.max()
# Out:
# 27.0

# %%
X=data[['TV','Radio','Newspaper']]
y=data['Sales']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
import seaborn as sb

# %%
# %matplotlib inline

# %%
sb.pairplot(data,x_vars=['TV','Radio','Newspaper'],y_vars=['Sales'],height=7)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train.shape
# Out:
# (150, 3)

# %%
linreg=LinearRegression()
linreg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=linreg.predict(X_test)
rmse=np.sqrt(mean_squared_error(y_test,y_pred))
print(rmse)
# Out:
# 1.5350557940957992

# %%
#Newspaper has weak correlation with target so lets try dropping it

# %%
X=data[['TV','Radio']]
y=data['Sales']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train.shape
# Out:
# (150, 2)

# %%
linreg=LinearRegression()
linreg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=linreg.predict(X_test)
rmse=np.sqrt(mean_squared_error(y_test,y_pred))
print(rmse)
# Out:
# 1.5350557940957992
